# %% [markdown]
# # Census Income project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# importing all the nessasary lybraries such as pandas,numpy,seabron and matplotlib and also warnings

# %%
df=pd.read_csv('census_income.csv')
df
# Out:
#        Age          Workclass  Fnlwgt    Education  Education_num  \
# 0       50   Self-emp-not-inc   83311    Bachelors             13
# 1       38            Private  215646      HS-grad              9
# 2       53            Private  234721         11th              7
# 3       28            Private  338409    Bachelors             13
# 4       37            Private  284582      Masters             14
# ...    ...                ...     ...          ...            ...
# 32555   27            Private  257302   Assoc-acdm             12
# 32556   40            Private  154374      HS-grad              9
# 32557   58            Private  151910      HS-grad              9
# 32558   22            Private  201490      HS-grad              9
# 32559   52       Self-emp-inc  287927      HS-grad              9
#
#             Marital_status          Occupation    Relationship    Race  \
# 0       Married-civ-spouse     Exec-managerial         Husband   White
# ...

# %% [markdown]
# Loading the dataset from my jupyter notebook,which is previously saved in my jupyter notebook

# %%
df.isnull().sum()
# Out:
# Age               0
# Workclass         0
# Fnlwgt            0
# Education         0
# Education_num     0
# Marital_status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital_gain      0
# Capital_loss      0
# Hours_per_week    0
# Native_country    0
# Income            0
# dtype: int64

# %% [markdown]
# checking for the null values in the dataset,there is no null values present

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %% [markdown]
# the columns present in the dataset

# %%
df['Income'].value_counts()
# Out:
#  <=50K    24719
#  >50K      7841
# Name: Income, dtype: int64

# %% [markdown]
# values present in the income columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32560 entries, 0 to 32559
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             32560 non-null  int64
#  1   Workclass       32560 non-null  object
#  2   Fnlwgt          32560 non-null  int64
#  3   Education       32560 non-null  object
#  4   Education_num   32560 non-null  int64
#  5   Marital_status  32560 non-null  object
#  6   Occupation      32560 non-null  object
#  7   Relationship    32560 non-null  object
#  8   Race            32560 non-null  object
#  9   Sex             32560 non-null  object
#  10  Capital_gain    32560 non-null  int64
#  11  Capital_loss    32560 non-null  int64
#  12  Hours_per_week  32560 non-null  int64
#  13  Native_country  32560 non-null  object
#  14  Income          32560 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %% [markdown]
# there are  32560 entries are present in each columns and 15 columns are present and using the memory of 3.7MB

# %%
df.dtypes
# Out:
# Age                int64
# Workclass         object
# Fnlwgt             int64
# Education         object
# Education_num      int64
# Marital_status    object
# Occupation        object
# Relationship      object
# Race              object
# Sex               object
# Capital_gain       int64
# Capital_loss       int64
# Hours_per_week     int64
# Native_country    object
# Income            object
# dtype: object

# %% [markdown]
# 2 types of data is present in the dataset , they are object and integer type

# %%
df.describe()
# Out:
#                 Age        Fnlwgt  Education_num  Capital_gain  Capital_loss  \
# count  32560.000000  3.256000e+04   32560.000000  32560.000000  32560.000000
# mean      38.581634  1.897818e+05      10.080590   1077.615172     87.306511
# std       13.640642  1.055498e+05       2.572709   7385.402999    402.966116
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178315e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783630e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370545e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        Hours_per_week
# count    32560.000000
# mean        40.437469
# std         12.347618
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %% [markdown]
# Stastistical analysis

# %% [markdown]
# * there are 32560 rows are present in each columns
# * the Mean is greater than the median , it means there is right skewed data is present
# * Except Fnlwgt and Education_num columns all pther columns are having Standard deviation is morethan the 3, means outliers are
#   present we need to remove them further
# * the diffence between 75% and max values are high in some columns , it indecates outliers need to remove.
# * Capital_gain and Capital_loss columns more outliers ,because only max values present in this columns

# %% [markdown]
# # Extradetory Data Analysis

# %%
df.columns
# Out:
# Index(['Age', 'Workclass', 'Fnlwgt', 'Education', 'Education_num',
#        'Marital_status', 'Occupation', 'Relationship', 'Race', 'Sex',
#        'Capital_gain', 'Capital_loss', 'Hours_per_week', 'Native_country',
#        'Income'],
#       dtype='object')

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='Workclass',data=df)
df['Workclass'].value_counts()
# Out:
#  Private             22696
#  Self-emp-not-inc     2541
#  Local-gov            2093
#  ?                    1836
#  State-gov            1297
#  Self-emp-inc         1116
#  Federal-gov           960
#  Without-pay            14
#  Never-worked            7
# Name: Workclass, dtype: int64

# %%
plt.figure(figsize=(20,4))
sns.countplot(x='Education',data=df)
df['Education'].value_counts()
# Out:
#  HS-grad         10501
#  Some-college     7291
#  Bachelors        5354
#  Masters          1723
#  Assoc-voc        1382
#  11th             1175
#  Assoc-acdm       1067
#  10th              933
#  7th-8th           646
#  Prof-school       576
#  9th               514
#  12th              433
#  Doctorate         413
#  5th-6th           333
#  1st-4th           168
#  Preschool          51
# Name: Education, dtype: int64

# %%
p=1
for i in df.columns:
    if df[i].dtypes=='object':
        if p<25:
            plt.figure(figsize=(20,50))
            plt.subplot(10,1,p)
            sns.countplot(x=df[i])
            plt.xlabel(i)
        p+=1
    plt.show()

# %% [markdown]
# using the countplot analysing the values counts of object datatype columns

# %%
sns.pairplot(data=df)

# %% [markdown]
# using the pairplot to check the distribution of the data with respect to the each columns

# %%
plt.figure(figsize=(50,10))
sns.catplot(x='Age',y='Workclass',hue='Income',data=df,kind='bar')

# %% [markdown]
# Aged more than 40years are getting more income and they are more tax payers also

# %%
sns.catplot(y='Occupation',x='Income',hue='Sex',data=df)

# %% [markdown]
# females are Earning less than 50K are more  and they are least number of taxpayers

# %%
sns.scatterplot(y='Capital_gain',x='Income',hue='Sex',data=df)
# Out:
# <AxesSubplot:xlabel='Income', ylabel='Capital_gain'>

# %% [markdown]
# Capital gain is more with the taxpayers ,means who is earning more then 50K

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='Relationship',hue='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Relationship', ylabel='count'>

# %% [markdown]
# Husband is only person who is earning more and paying

# %%
plt.figure(figsize=(15,4))
sns.catplot(y='Race',x='Age',hue='Income',data=df,kind='bar')

# %% [markdown]
# all Race peoples are equally getting income

# %%
plt.figure(figsize=(15,4))
sns.countplot(x='Marital_status',hue='Income',data=df)
# Out:
# <AxesSubplot:xlabel='Marital_status', ylabel='count'>

# %% [markdown]
# Married-civ-spouse are earning more income compared to the others

# %%
from sklearn.preprocessing import OrdinalEncoder

# %%
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 3       28        4.0  338409        9.0             13             2.0
# 4       37        4.0  284582       12.0             14             2.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %% [markdown]
# Using the OrdinalEncoder to convert the object data into numarical data

# %%
plt.figure(figsize=(20,35))
p=1

for i in df.columns:
    if p<25:
        plt.subplot(8,3,p)
        sns.boxplot(data=df[i])
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# with the help of Boxplot we can see that there are more outliers are present in the
#
# 1)Capital_loss
#
# 2)Capital_gain
#
# we need to remove the outliers

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.837097   1.463883  1.008742   0.335443       1.134779
# 1      0.042640   0.090121  0.245046   0.181319       0.420027
# 2      1.057031   0.090121  0.425770   2.402489       1.197429
# 3      0.775755   0.090121  1.408146   0.335443       1.134779
# 4      0.115952   0.090121  0.898170   0.439700       1.523480
# ...         ...        ...       ...        ...            ...
# 32555  0.849066   0.090121  0.639710   0.852204       0.746077
# 32556  0.103982   0.090121  0.335466   0.181319       0.420027
# 32557  1.423589   0.090121  0.358811   0.181319       0.420027
# 32558  1.215624   0.090121  0.110927   0.181319       0.420027
# 32559  0.983720   0.777002  0.929862   0.181319       0.420027
#
#        Marital_status  Occupation  Relationship      Race       Sex  \
# 0            0.406183    0.608434      0.900177  0.393675  0.703087
# 1            1.734026    0.135480      0.277810  0.393675  0.703087
# ...

# %% [markdown]
# Using Zscore method to remove the outliers

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([    3,     9,    10, ..., 32532, 32550, 32552], dtype=int64), array([13, 12,  8, ...,  8,  8,  8], dtype=int64))

# %% [markdown]
# setting the threshold to 3,because 99.9% of the data is present in the range of +3 to -3 standard deviations

# %%
df1=df[(z<3).all(axis=1)]
df1
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 4       37        4.0  284582       12.0             14             2.0
# 5       49        4.0  160187        6.0              5             3.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Race  Sex  Capital_gain  Capital_loss  \
# ...

# %% [markdown]
# after removing the outliers , saving in the new variable df1

# %%
plt.figure(figsize=(20,25))
p=1

for i in df1.columns:
    if p<25:
        plt.subplot(8,3,p)
        sns.boxplot(data=df1[i])
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# still outliers are present we need drop some columns

# %%
df1.drop(['Capital_gain'],axis=1,inplace=True)

# %%
df1.drop(['Capital_loss'],axis=1,inplace=True)

# %%
df1.drop(['Native_country'],axis=1,inplace=True)

# %%
plt.figure(figsize=(20,35))
p=1

for i in df1.columns:
    if p<25:
        plt.subplot(8,3,p)
        sns.boxplot(data=df1[i])
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# now we can see that almost outliers are removed

# %%
df1.skew()
# Out:
# Age               0.483478
# Workclass        -0.738023
# Fnlwgt            0.626221
# Education        -0.957458
# Education_num    -0.143960
# Marital_status   -0.044317
# Occupation        0.131148
# Relationship      0.750207
# Race             -2.592931
# Sex              -0.684115
# Hours_per_week   -0.358396
# Income            1.324919
# dtype: float64

# %% [markdown]
# some columns has skewness, we need to remove the skewness

# %%
df1['Race']=np.sqrt(df1['Race'])

# %% [markdown]
# using numpy cube root method to remove the skewness

# %%
df1.skew()
# Out:
# Age               0.483478
# Workclass        -0.738023
# Fnlwgt            0.626221
# Education        -0.957458
# Education_num    -0.143960
# Marital_status   -0.044317
# Occupation        0.131148
# Relationship      0.750207
# Race             -2.600822
# Sex              -0.684115
# Hours_per_week   -0.358396
# Income            1.324919
# dtype: float64

# %%
plt.figure(figsize=(20,25))
p=1

for i in df1.columns:
    if p<25:
        plt.subplot(8,3,p)
        sns.distplot(df1[i])
        plt.xlabel(i)
    p+=1
plt.show()

# %% [markdown]
# now skewness is removed from the dataset

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# importing vif function to check the biasness of the data

# %%
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(df1.values,i)
                    for i in range(len(df1.columns))]
vif['VIF Features']=df1.columns
vif
# Out:
#     VIF Values    VIF Features
# 0     9.632707             Age
# 1     8.735326       Workclass
# 2     4.656006          Fnlwgt
# 3     9.210082       Education
# 4    23.056659   Education_num
# 5     4.214425  Marital_status
# 6     3.665566      Occupation
# 7     2.785020    Relationship
# 8    46.366805            Race
# 9     4.533930             Sex
# 10   15.065855  Hours_per_week
# 11    1.611843          Income

# %% [markdown]
# Race column has high vif value , i am droping the Race column to reduce the vif value

# %%
df1.drop(['Race'],axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['VIF values']=[variance_inflation_factor(df1.values,i)
                  for i in range(len(df1.columns))]
vif['VIF Features']=df1.columns
vif
# Out:
#     VIF values    VIF Features
# 0     8.002482             Age
# 1     8.287380       Workclass
# 2     4.535300          Fnlwgt
# 3     9.055494       Education
# 4    19.995831   Education_num
# 5     3.903594  Marital_status
# 6     3.658272      Occupation
# 7     2.539282    Relationship
# 8     4.185834             Sex
# 9    13.535997  Hours_per_week
# 10    1.582325          Income

# %% [markdown]
# now vif values are reduced and are in range

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()

# %% [markdown]
# Using the StandardScaler to standardize the values

# %%
x=df1.iloc[:,:-1]
x
# Out:
#        Age  Workclass  Fnlwgt  Education  Education_num  Marital_status  \
# 0       50        6.0   83311        9.0             13             2.0
# 1       38        4.0  215646       11.0              9             0.0
# 2       53        4.0  234721        1.0              7             2.0
# 4       37        4.0  284582       12.0             14             2.0
# 5       49        4.0  160187        6.0              5             3.0
# ...    ...        ...     ...        ...            ...             ...
# 32555   27        4.0  257302        7.0             12             2.0
# 32556   40        4.0  154374       11.0              9             2.0
# 32557   58        4.0  151910       11.0              9             6.0
# 32558   22        4.0  201490       11.0              9             4.0
# 32559   52        5.0  287927       11.0              9             2.0
#
#        Occupation  Relationship  Sex  Hours_per_week
# ...

# %% [markdown]
# separating the independent values as x

# %%
y=df1['Income']
y
# Out:
# 0        0.0
# 1        0.0
# 2        0.0
# 4        0.0
# 5        0.0
#         ...
# 32555    0.0
# 32556    1.0
# 32557    0.0
# 32558    0.0
# 32559    1.0
# Name: Income, Length: 27417, dtype: float64

# %% [markdown]
# separated dependent variable as y

# %%
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#             Age  Workclass    Fnlwgt  Education  Education_num  \
# 0      0.882739   1.474391 -1.086327  -0.345725       1.221891
# 1     -0.011737   0.092844  0.310209   0.169985      -0.438259
# 2      1.106358   0.092844  0.511508  -2.408564      -1.268334
# 3     -0.086276   0.092844  1.037693   0.427839       1.636928
# 4      0.808199   0.092844 -0.275052  -1.119290      -2.098409
# ...         ...        ...       ...        ...            ...
# 27412 -0.831673   0.092844  0.749806  -0.861435       0.806853
# 27413  0.137342   0.092844 -0.336397   0.169985      -0.438259
# 27414  1.479056   0.092844 -0.362399   0.169985      -0.438259
# 27415 -1.204371   0.092844  0.160820   0.169985      -0.438259
# 27416  1.031818   0.783618  1.072993   0.169985      -0.438259
#
#        Marital_status  Occupation  Relationship       Sex  Hours_per_week
# 0           -0.403219   -0.599291     -0.915305  0.714839       -2.412190
# ...

# %% [markdown]
# standardizing the values with mean zero and std -1 to +1

# %%
y.value_counts()
# Out:
# 0.0    21279
# 1.0     6138
# Name: Income, dtype: int64

# %% [markdown]
# target variable not having equal number of predictions , we need to equal the samples

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %% [markdown]
# using the Smote function to resample the dataset

# %%
y.value_counts()
# Out:
# 0.0    21279
# 1.0    21279
# Name: Income, dtype: int64

# %% [markdown]
# # Modelling

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %% [markdown]
# importing models for prediction of model and train,test,split and also accuracy score,classification report,confusion matrix also

# %%
maxAccu=0
maxRs=0

for i in range(1,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    accu=accuracy_score(y_test,pred)
    if accu>maxAccu:
        maxAccu=accu
        maxRs=i
print('Best Accuracy_score is ',maxAccu,'at random state',maxRs)
# Out:
# Best Accuracy_score is  0.8481359649122807 at random state 721

# %% [markdown]
# checking for the best random state using the DecisionTreeClassifier

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRs)
from sklearn.svm import SVC
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier

# %% [markdown]
# importing other models for modelling

# %%
print('Support Vector ')
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
predsvc_train=svc.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predsvc)*100)
print('Accuracy score on train data',accuracy_score(y_train,predsvc_train)*100)
print('Classification report','\n',classification_report(y_test,predsvc))
print('Confusion Matrix','\n',confusion_matrix(y_test,predsvc))
# Out:
# Support Vector
# Accuracy score on test data 82.08020050125313
# Accuracy score on train data 82.63175562269218
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.75      0.81      6448
#          1.0       0.78      0.89      0.83      6320
#
#     accuracy                           0.82     12768
#    macro avg       0.83      0.82      0.82     12768
# weighted avg       0.83      0.82      0.82     12768
#
# Confusion Matrix
#  [[4825 1623]
#  [ 665 5655]]

# %% [markdown]
# with Support vector mission the accuracy score is 82%

# %%
print('GradientBoostingClassifier')
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
predgb=gb.predict(x_test)
predgb_train=gb.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predgb)*100)
print('Accuracy score on train data ',accuracy_score(y_train,predgb_train)*100)
print('Classification Report','\n',classification_report(y_test,predgb))
print('Confusion Matrix','\n',confusion_matrix(y_test,predgb))
# Out:
# GradientBoostingClassifier
# Accuracy score on test data 85.42449874686717
# Accuracy score on train data  85.60590802282645
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.81      0.85      6448
#          1.0       0.82      0.90      0.86      6320
#
#     accuracy                           0.85     12768
#    macro avg       0.86      0.85      0.85     12768
# weighted avg       0.86      0.85      0.85     12768
#
# Confusion Matrix
#  [[5230 1218]
#  [ 643 5677]]

# %% [markdown]
# with GradientBoostingClassifier the accuracy score is 85%

# %%
print('AdaBoostClassifier')
ab=AdaBoostClassifier()
ab.fit(x_train,y_train)
predab=ab.predict(x_test)
predab_train=ab.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predab)*100)
print('Accuracy score on train data ',accuracy_score(y_train,predab_train)*100)
print('Classification report ','\n',classification_report(y_test,predab))
print('Confusion Matrix','\n',confusion_matrix(y_test,predab))
# Out:
# AdaBoostClassifier
# Accuracy score on test data 83.51347117794487
# Accuracy score on train data  83.4441087613293
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.86      0.80      0.83      6448
#          1.0       0.81      0.87      0.84      6320
#
#     accuracy                           0.84     12768
#    macro avg       0.84      0.84      0.84     12768
# weighted avg       0.84      0.84      0.84     12768
#
# Confusion Matrix
#  [[5184 1264]
#  [ 841 5479]]

# %% [markdown]
# with AdaboostClassifier the accuracy score is 83%

# %%
print('BaggingClassifier')
bg=BaggingClassifier()
bg.fit(x_train,y_train)
predbg=bg.predict(x_test)
predbg_train=bg.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predbg)*100)
print('Accuracy score on train data ',accuracy_score(y_train,predbg_train)*100)
print('Classification Report','\n',classification_report(y_test,predbg))
print('Confusion Matrix','\n',confusion_matrix(y_test,predbg))
# Out:
# BaggingClassifier
# Accuracy score on test data 87.26503759398496
# Accuracy score on train data  99.1775763679087
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.87      0.87      6448
#          1.0       0.87      0.87      0.87      6320
#
#     accuracy                           0.87     12768
#    macro avg       0.87      0.87      0.87     12768
# weighted avg       0.87      0.87      0.87     12768
#
# Confusion Matrix
#  [[5621  827]
#  [ 799 5521]]

# %% [markdown]
# with BaggingClassifier the accuracy score is 87%

# %%
print('RandomForestClaasifier')
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
predrf_train=rf.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predrf)*100)
print('Accuracy score on train data',accuracy_score(y_train,predrf_train)*100)
print('Classification Report ','\n',classification_report(y_test,predrf))
print('Confusion Matrix','\n',confusion_matrix(y_test,predrf))
# Out:
# RandomForestClaasifier
# Accuracy score on test data 88.66697994987469
# Accuracy score on train data 99.99328633769721
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.91      0.86      0.88      6448
#          1.0       0.87      0.91      0.89      6320
#
#     accuracy                           0.89     12768
#    macro avg       0.89      0.89      0.89     12768
# weighted avg       0.89      0.89      0.89     12768
#
# Confusion Matrix
#  [[5566  882]
#  [ 565 5755]]

# %% [markdown]
# with RandomForestClassifier the accuracy score is 88% and on train data its showing accuracy of 99% it means , my model is
# showing overfitting

# %%
print('ExtraTreesClassifier')
et=ExtraTreesClassifier()
et.fit(x_train,y_train)
predet=et.predict(x_test)
predet_train=et.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predet)*100)
print('Accuracy score on train data',accuracy_score(y_train,predet_train)*100)
print('Classification Report','\n',classification_report(y_test,predet))
print('Confusion Matrix','\n',confusion_matrix(y_test,predet))
# Out:
# ExtraTreesClassifier
# Accuracy score on test data 89.47368421052632
# Accuracy score on train data 99.99328633769721
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.92      0.87      0.89      6448
#          1.0       0.87      0.92      0.90      6320
#
#     accuracy                           0.89     12768
#    macro avg       0.90      0.89      0.89     12768
# weighted avg       0.90      0.89      0.89     12768
#
# Confusion Matrix
#  [[5602  846]
#  [ 498 5822]]

# %% [markdown]
# with ExtraTreesClassifier accuracy score is 89% and its also showing overfitting

# %%
print('DecisionTreeClassifier')
dtc.fit(x_train,y_train)
preddtc=dtc.predict(x_test)
preddtc_train=dtc.predict(x_train)
print('Accuracy score on test data ',accuracy_score(y_test,preddtc)*100)
print('Accuracy score on train data ',accuracy_score(y_train,preddtc_train)*100)
print('Classification Report','\n',classification_report(y_test,preddtc))
print('Confusion Matrix','\n',confusion_matrix(y_test,preddtc))
# Out:
# DecisionTreeClassifier
# Accuracy score on test data  84.359335839599
# Accuracy score on train data  99.99328633769721
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.85      0.83      0.84      6448
#          1.0       0.83      0.85      0.84      6320
#
#     accuracy                           0.84     12768
#    macro avg       0.84      0.84      0.84     12768
# weighted avg       0.84      0.84      0.84     12768
#
# Confusion Matrix
#  [[5375 1073]
#  [ 924 5396]]

# %% [markdown]
# with DecisionTreeClassifier the accuracy score 84% and dtc also showing overfitting

# %%
from sklearn.naive_bayes import MultinomialNB,GaussianNB

# %%
print('GaussianNB')
gnb=GaussianNB()
gnb.fit(x_train,y_train)
predgnb=gnb.predict(x_test)
predgnb_train=gnb.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predgnb)*100)
print('Accuracy score on train data ',accuracy_score(y_train,predgnb_train)*100)
print('Classification Report','\n',classification_report(y_test,predgnb))
print('Confusion Matrix','\n',confusion_matrix(y_test,predgnb))
# Out:
# GaussianNB
# Accuracy score on test data 76.91102756892231
# Accuracy score on train data  76.28398791540786
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.78      0.75      0.77      6448
#          1.0       0.75      0.79      0.77      6320
#
#     accuracy                           0.77     12768
#    macro avg       0.77      0.77      0.77     12768
# weighted avg       0.77      0.77      0.77     12768
#
# Confusion Matrix
#  [[4824 1624]
#  [1324 4996]]

# %% [markdown]
# with GaussionNB the accuracy score is 76%

# %%
from sklearn.model_selection import cross_val_score

# %% [markdown]
# to overcome from overfitting and underfitting of the model using cross validation technique

# %%
print('DecisionTreeClassifier')
scoredtc=cross_val_score(dtc,x,y,cv=10)
print('Score',scoredtc*100)
print('Mean',scoredtc.mean()*100)
# Out:
# DecisionTreeClassifier
# Score [73.80169173 75.35244361 76.99718045 88.53383459 87.54699248 88.39285714
#  88.51033835 89.52067669 87.84958872 88.31962397]
# Mean 84.48252277285458

# %%
print('GradientBoostClassifier')
scoregb=cross_val_score(gb,x,y,cv=10)
print('score',scoregb*100)
print('Mean score',scoregb.mean()*100)
# Out:
# GradientBoostClassifier
# score [80.28665414 80.99154135 81.95488722 86.84210526 86.7481203  86.91259398
#  87.80545113 87.40601504 86.95652174 86.9800235 ]
# Mean score 85.28839136619457

# %%
print('AdaBoostClassifer')
scoreab=cross_val_score(ab,x,y,cv=10)
print('score',scoreab*100)
print('Mean score',scoreab.mean()*100)
# Out:
# AdaBoostClassifer
# score [80.45112782 81.08552632 81.10902256 84.23402256 84.18703008 84.72744361
#  85.40883459 84.82142857 83.99529965 84.48883666]
# Mean score 83.4508572400449

# %%
print('ExtraTreesClassifier')
scoreet=cross_val_score(et,x,y,cv=10)
print('score',scoreet*100)
print('Mean score',scoreet.mean()*100)
# Out:
# ExtraTreesClassifier
# score [84.11654135 84.42199248 86.20770677 92.38721805 91.91729323 92.17575188
#  92.85714286 92.73966165 92.50293772 92.29142186]
# Mean score 90.1617667847645

# %%
print('RandomForestClassifier')
scorerf=cross_val_score(rf,x,y,cv=10)
print('score',scorerf*100)
print('Mean score',scorerf.mean()*100)
# Out:
# RandomForestClassifier
# score [81.17951128 81.86090226 83.43515038 92.05827068 91.4943609  92.1287594
#  92.83364662 92.50469925 92.29142186 91.91539365]
# Mean score 89.1702116263043

# %%
print('BaggingClassifier')
scorebg=cross_val_score(bg,x,y,cv=10)
print('score',scorebg*100)
print('Mean score',scorebg.mean()*100)
# Out:
# BaggingClassifier
# score [76.83270677 78.17199248 79.44078947 91.79981203 91.21240602 91.68233083
#  92.08176692 92.50469925 91.37485311 91.91539365]
# Mean score 87.7016750527906

# %%
print('Support vector')
scoresvc=cross_val_score(svc,x,y,cv=10)
print('score',scoresvc*100)
print('Mean score',scoresvc.mean()*100)
# Out:
# Support vector
# score [81.71992481 81.71992481 81.69642857 81.53195489 81.48496241 82.18984962
#  82.9887218  82.40131579 82.63219741 82.63219741]
# Mean score 82.09974775363791

# %%
print('GaussionNB')
scoregnb=cross_val_score(gnb,x,y,cv=10)
print('Score',scoregnb*100)
print('Mean score',scoregnb.mean()*100)
# Out:
# GaussionNB
# Score [76.03383459 76.45676692 76.52725564 76.33928571 75.93984962 75.93984962
#  76.71522556 76.99718045 76.02820212 76.94477086]
# Mean score 76.39222210932736

# %% [markdown]
# after cross validation the best performing model is ExtraTreesClassifier with accuracy score of 90%

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Using GridSearchCV to find the best working parameters to my model

# %%
parameters={'criterion':['gini','entropy'],
           'n_jobs':[-2,-1,1],
           'max_depth':[50,100,150],
           'random_state':[100,200,500],
           'n_estimators':[50,100,150]}

# %% [markdown]
# setting the best parameters to new model

# %%
gscv=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'criterion': 'entropy',
#  'max_depth': 100,
#  'n_estimators': 150,
#  'n_jobs': -2,
#  'random_state': 100}

# %% [markdown]
# after GridSearchCV the best parameters are above parameters

# %%
model=ExtraTreesClassifier(criterion='entropy',max_depth=100,n_jobs=-2,random_state=100,n_estimators=150)

# %% [markdown]
# Building the model with best parameters

# %%
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('Accuracy score is ',accuracy_score(y_test,pred)*100)
print('Classification_report','\n',classification_report(y_test,pred))
print('Confusion_matrix','\n',confusion_matrix(y_test,pred))
# Out:
# Accuracy score is  89.44235588972431
# Classification_report
#                precision    recall  f1-score   support
#
#          0.0       0.92      0.86      0.89      6448
#          1.0       0.87      0.92      0.90      6320
#
#     accuracy                           0.89     12768
#    macro avg       0.90      0.89      0.89     12768
# weighted avg       0.90      0.89      0.89     12768
#
# Confusion_matrix
#  [[5577  871]
#  [ 477 5843]]

# %% [markdown]
# checking the models accuracy score with best parameters

# %%
import pickle
filename='Census_income'
pickle.dump(model,open(filename,'wb'))

# %% [markdown]
# with the help of pickle lybrari saving the model in the jupyter notebook

# %%
final_pred_model=pickle.load(open('Census_income','rb'))
final_pred_model.score(x_test,y_test)*100
# Out:
# 89.44235588972431

# %% [markdown]
# Loading the model from jupyter notebook and checking for the accuracy score

# %% [markdown]
# Conclusion
