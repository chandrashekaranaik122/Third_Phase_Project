# %% [markdown]
# # Insurance Fraud Project

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# importing all the nessasary lybraries such as pandas,numpy,seaborn and matplot

# %%
df=pd.read_csv('insurance.csv')
df
# Out:
#      months_as_customer  age  policy_number policy_bind_date policy_state  \
# 0                   328   48         521585       17-10-2014           OH
# 1                   228   42         342868       27-06-2006           IN
# 2                   134   29         687698       06-09-2000           OH
# 3                   256   41         227811       25-05-1990           IL
# 4                   228   44         367455       06-06-2014           IL
# ..                  ...  ...            ...              ...          ...
# 995                   3   38         941851       16-07-1991           OH
# 996                 285   41         186934       05-01-2014           IL
# 997                 130   34         918516       17-02-2003           OH
# 998                 458   62         533940       18-11-2011           IL
# 999                 456   60         556080       11-11-1996           OH
#
#     policy_csl  policy_deductable  policy_annual_premium  umbrella_limit  \
# ...

# %% [markdown]
# loading the dataset insurance from my jupyter notebook which is saved

# %%
df.columns
# Out:
# Index(['months_as_customer', 'age', 'policy_number', 'policy_bind_date',
#        'policy_state', 'policy_csl', 'policy_deductable',
#        'policy_annual_premium', 'umbrella_limit', 'insured_zip', 'insured_sex',
#        'insured_education_level', 'insured_occupation', 'insured_hobbies',
#        'insured_relationship', 'capital-gains', 'capital-loss',
#        'incident_date', 'incident_type', 'collision_type', 'incident_severity',
#        'authorities_contacted', 'incident_state', 'incident_city',
#        'incident_location', 'incident_hour_of_the_day',
#        'number_of_vehicles_involved', 'property_damage', 'bodily_injuries',
#        'witnesses', 'police_report_available', 'total_claim_amount',
#        'injury_claim', 'property_claim', 'vehicle_claim', 'auto_make',
#        'auto_model', 'auto_year', 'fraud_reported', '_c39'],
#       dtype='object')

# %% [markdown]
# columns consisting of insurance dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 40 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   months_as_customer           1000 non-null   int64
#  1   age                          1000 non-null   int64
#  2   policy_number                1000 non-null   int64
#  3   policy_bind_date             1000 non-null   object
#  4   policy_state                 1000 non-null   object
#  5   policy_csl                   1000 non-null   object
#  6   policy_deductable            1000 non-null   int64
#  7   policy_annual_premium        1000 non-null   float64
#  8   umbrella_limit               1000 non-null   int64
#  9   insured_zip                  1000 non-null   int64
#  10  insured_sex                  1000 non-null   object
#  11  insured_education_level      1000 non-null   object
#  12  insured_occupation           1000 non-null   object
# ...

# %% [markdown]
# there are 40 columns and 1000 rows present in the dataset and using the memory of 312.6+ kb

# %%
df.dtypes
# Out:
# months_as_customer               int64
# age                              int64
# policy_number                    int64
# policy_bind_date                object
# policy_state                    object
# policy_csl                      object
# policy_deductable                int64
# policy_annual_premium          float64
# umbrella_limit                   int64
# insured_zip                      int64
# insured_sex                     object
# insured_education_level         object
# insured_occupation              object
# insured_hobbies                 object
# insured_relationship            object
# capital-gains                    int64
# capital-loss                     int64
# incident_date                   object
# incident_type                   object
# collision_type                  object
# incident_severity               object
# authorities_contacted           object
# incident_state                  object
# incident_city                   object
# ...

# %% [markdown]
# 3 types of data is present in the dataset and they are integer,float and object types
#
# further we need convert the object data into numarical data

# %%
df.isnull().sum()
# Out:
# months_as_customer                0
# age                               0
# policy_number                     0
# policy_bind_date                  0
# policy_state                      0
# policy_csl                        0
# policy_deductable                 0
# policy_annual_premium             0
# umbrella_limit                    0
# insured_zip                       0
# insured_sex                       0
# insured_education_level           0
# insured_occupation                0
# insured_hobbies                   0
# insured_relationship              0
# capital-gains                     0
# capital-loss                      0
# incident_date                     0
# incident_type                     0
# collision_type                    0
# incident_severity                 0
# authorities_contacted             0
# incident_state                    0
# incident_city                     0
# incident_location                 0
# incident_hour_of_the_day          0
# ...

# %% [markdown]
# _c39 columns not having any data ,we need to remove this column

# %%
for i in df.columns:
    print('*'*15,'\n',i,'\n','*'*15,'\n',df[i].value_counts())
# Out:
# ***************
#  months_as_customer
#  ***************
#  194    8
# 128    7
# 254    7
# 140    7
# 210    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: months_as_customer, Length: 391, dtype: int64
# ***************
#  age
#  ***************
#  43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: age, dtype: int64
# ***************
#  policy_number
#  ***************
#  521585    1
# 687755    1
# 674485    1
# 223404    1
# 991480    1
#          ..
# 563878    1
# 620855    1
# 583169    1
# ...

# %% [markdown]
# checking for value counts in the dataset
#
# except the _c39 column other columns are having data

# %%
for i in df.columns:
    print(i,'*'*20,df[i].nunique())
# Out:
# months_as_customer ******************** 391
# age ******************** 46
# policy_number ******************** 1000
# policy_bind_date ******************** 951
# policy_state ******************** 3
# policy_csl ******************** 3
# policy_deductable ******************** 3
# policy_annual_premium ******************** 991
# umbrella_limit ******************** 11
# insured_zip ******************** 995
# insured_sex ******************** 2
# insured_education_level ******************** 7
# insured_occupation ******************** 14
# insured_hobbies ******************** 20
# insured_relationship ******************** 6
# capital-gains ******************** 338
# capital-loss ******************** 354
# incident_date ******************** 60
# incident_type ******************** 4
# collision_type ******************** 4
# incident_severity ******************** 4
# authorities_contacted ******************** 5
# incident_state ******************** 7
# incident_city ******************** 7
# ...

# %% [markdown]
# number of uqniues values present in each column and there is no values in _c39

# %%
for i in df.columns:
    if df[i].dtypes=='object':
        print('*'*50,'\n',i,
              '---',df[i].dtypes,'(datatype)',
              '\n','*'*50,'\n',
              df[i].value_counts())
# Out:
# **************************************************
#  policy_bind_date --- object (datatype)
#  **************************************************
#  01-01-2006    3
# 28-04-1992    3
# 05-08-1992    3
# 14-12-1991    2
# 09-08-2004    2
#              ..
# 03-06-2014    1
# 12-12-1998    1
# 18-02-1999    1
# 30-10-1997    1
# 11-11-1996    1
# Name: policy_bind_date, Length: 951, dtype: int64
# **************************************************
#  policy_state --- object (datatype)
#  **************************************************
#  OH    352
# IL    338
# IN    310
# Name: policy_state, dtype: int64
# **************************************************
#  policy_csl --- object (datatype)
#  **************************************************
#  250/500     351
# 100/300     349
# 500/1000    300
# Name: policy_csl, dtype: int64
# **************************************************
#  insured_sex --- object (datatype)
#  **************************************************
# ...

# %% [markdown]
# value counts in the object datatype column

# %%
for i in df.columns:
    if df[i].dtypes=='int64':
        print('-'*25,'\n',
              i,'---',df[i].dtypes,'(datatype)''\n',
              '-'*25,'\n',df[i].value_counts())
# Out:
# -------------------------
#  months_as_customer --- int64 (datatype)
#  -------------------------
#  194    8
# 128    7
# 254    7
# 140    7
# 210    7
#       ..
# 390    1
# 411    1
# 453    1
# 448    1
# 17     1
# Name: months_as_customer, Length: 391, dtype: int64
# -------------------------
#  age --- int64 (datatype)
#  -------------------------
#  43    49
# 39    48
# 41    45
# 34    44
# 38    42
# 30    42
# 31    42
# 37    41
# 33    39
# 40    38
# 32    38
# 29    35
# 46    33
# 42    32
# 35    32
# 36    32
# 44    32
# 28    30
# 26    26
# 45    26
# 48    25
# 47    24
# 27    24
# 57    16
# 25    14
# 55    14
# 49    14
# 53    13
# 50    13
# 24    10
# 54    10
# 61    10
# 51     9
# 60     9
# 58     8
# 56     8
# 23     7
# 21     6
# 59     5
# 62     4
# 52     4
# 64     2
# 63     2
# 19     1
# 20     1
# 22     1
# Name: age, dtype: int64
# -------------------------
#  policy_number --- int64 (datatype)
#  -------------------------
# ...

# %% [markdown]
# values present in the integer datatype

# %%
for i in df.columns:
    if df[i].dtypes=='float64':
        print('*'*45,'\n',i,'---',
              df[i].dtypes,'(datatype)',
              '\n','*'*45,'\n',
              df[i].value_counts())
# Out:
# *********************************************
#  policy_annual_premium --- float64 (datatype)
#  *********************************************
#  1558.29    2
# 1215.36    2
# 1362.87    2
# 1073.83    2
# 1389.13    2
#           ..
# 1085.03    1
# 1437.33    1
# 988.29     1
# 1238.89    1
# 766.19     1
# Name: policy_annual_premium, Length: 991, dtype: int64
# *********************************************
#  _c39 --- float64 (datatype)
#  *********************************************
#  Series([], Name: _c39, dtype: int64)

# %% [markdown]
# values present in the float datatype columns and _c39 column showing float but not having any values
#
# we need to drop the _c39 column

# %%
df.drop(['_c39'],axis=1,inplace=True)

# %% [markdown]
# with the help of pandas drop method dropping the _c39 column

# %%
df.isnull().sum()
# Out:
# months_as_customer             0
# age                            0
# policy_number                  0
# policy_bind_date               0
# policy_state                   0
# policy_csl                     0
# policy_deductable              0
# policy_annual_premium          0
# umbrella_limit                 0
# insured_zip                    0
# insured_sex                    0
# insured_education_level        0
# insured_occupation             0
# insured_hobbies                0
# insured_relationship           0
# capital-gains                  0
# capital-loss                   0
# incident_date                  0
# incident_type                  0
# collision_type                 0
# incident_severity              0
# authorities_contacted          0
# incident_state                 0
# incident_city                  0
# incident_location              0
# incident_hour_of_the_day       0
# number_of_vehicles_involved    0
# property_damage                0
# ...

# %% [markdown]
# now there is no null values present in the dataset

# %%
df.describe()
# Out:
#        months_as_customer          age  policy_number  policy_deductable  \
# count         1000.000000  1000.000000    1000.000000        1000.000000
# mean           203.954000    38.948000  546238.648000        1136.000000
# std            115.113174     9.140287  257063.005276         611.864673
# min              0.000000    19.000000  100804.000000         500.000000
# 25%            115.750000    32.000000  335980.250000         500.000000
# 50%            199.500000    38.000000  533135.000000        1000.000000
# 75%            276.250000    44.000000  759099.750000        2000.000000
# max            479.000000    64.000000  999435.000000        2000.000000
#
#        policy_annual_premium  umbrella_limit    insured_zip  capital-gains  \
# count            1000.000000    1.000000e+03    1000.000000    1000.000000
# mean             1256.406150    1.101000e+06  501214.488000   25126.100000
# std               244.167395    2.297407e+06   71701.610941   27872.187708
# ...

# %% [markdown]
# Stastical Analysis

# %% [markdown]
# * Each columns has 1000 rows
#
# * The Mean is Greater than the median , it indicates right skewed data is present in the dataset.
#
# * The Standard deviation of all the columns are more than expected range , means outliers are present in the dataset.
#
# * The capital-gains column not having minimum value , 50% value and 75% value and capital-loss column not having 75% and max values..
#
# * Umbrella_limit column has only one value.
#
# * Mejority of the columns has huge difference between 75th percentile and maximum value.it indicates outliers are present we need to remove the outliers.
#
# * we need to remove the columns which has more number of outliers.

# %% [markdown]
# # Extradatory Data Analysis

# %%
sns.scatterplot(x='age',y='months_as_customer',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='months_as_customer'>

# %%
plt.figure(figsize=(25,6))
sns.countplot(x='umbrella_limit',data=df)
# Out:
# <AxesSubplot:xlabel='umbrella_limit', ylabel='count'>

# %%
sns.countplot(x='insured_sex',data=df)
print(df['insured_sex'].value_counts())
# Out:
# FEMALE    537
# MALE      463
# Name: insured_sex, dtype: int64

# %%
sns.scatterplot(y='age',x='policy_state',hue='insured_sex',data=df)
# Out:
# <AxesSubplot:xlabel='policy_state', ylabel='age'>

# %%
sns.countplot(x='collision_type',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='collision_type', ylabel='count'>

# %%
plt.figure(figsize=(15,4),facecolor='y')
sns.countplot(x='incident_hour_of_the_day',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='incident_hour_of_the_day', ylabel='count'>

# %%
plt.figure(figsize=(15,4),facecolor='m')
sns.countplot(x='insured_education_level',hue='fraud_reported',data=df,color='b')
# Out:
# <AxesSubplot:xlabel='insured_education_level', ylabel='count'>

# %%
plt.figure(figsize=(15,4),facecolor='r')
sns.countplot(x='auto_make',hue='fraud_reported',data=df,color='y')
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='count'>

# %%
plt.figure(figsize=(15,12))
sns.scatterplot(x='auto_make',y='auto_model',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='auto_make', ylabel='auto_model'>

# %%
plt.figure(figsize=(20,6))
sns.scatterplot(x='witnesses',y='incident_city',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='witnesses', ylabel='incident_city'>

# %%
sns.scatterplot(x='age',y='insured_zip',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='age', ylabel='insured_zip'>

# %%
plt.figure(figsize=(30,8))
sns.countplot(x='insured_hobbies',hue='fraud_reported',data=df)
# Out:
# <AxesSubplot:xlabel='insured_hobbies', ylabel='count'>

# %%
plt.figure(figsize=(30,100))
p=1

for i in df.columns:
    if df[i].dtypes=='int64':
        if p<50:
            plt.subplot(12,3,p)
            sns.boxplot(data=df[i])
            plt.xlabel(i)
        p+=1
plt.show()

# %% [markdown]
# umbrella_limit column has outliers

# %%
plt.figure(figsize=(10,20))
p=1

for i in df.columns:
    if df[i].dtypes=='float64':
        if p<30:
            plt.subplot(4,2,p)
            sns.boxplot(data=df[i])
            plt.xlabel(i)
        p+=1
        
plt.show()

# %% [markdown]
# policy_annual_premium column also has outliers , we need to clean it

# %%
from sklearn.preprocessing import OrdinalEncoder
oe=OrdinalEncoder()

for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=oe.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585             532.0           2.0
# 1                   228   42         342868             821.0           1.0
# 2                   134   29         687698             186.0           2.0
# 3                   256   41         227811             766.0           0.0
# 4                   228   44         367455             181.0           0.0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851             487.0           2.0
# 996                 285   41         186934             129.0           0.0
# 997                 130   34         918516             509.0           2.0
# 998                 458   62         533940             573.0           0.0
# 999                 456   60         556080             359.0           2.0
#
# ...

# %% [markdown]
# Using the Ordinal encoder to convert the string data into numarical data

# %%
from scipy.stats import zscore
z=np.abs(zscore(df))
z
# Out:
#      months_as_customer       age  policy_number  policy_bind_date  \
# 0              1.078140  0.990836       0.095953          0.209500
# 1              0.208995  0.334073       0.791527          1.259397
# 2              0.608002  1.088913       0.550566          1.047470
# 3              0.452355  0.224613       1.239334          1.059589
# 4              0.208995  0.552994       0.695834          1.065634
# ..                  ...       ...            ...               ...
# 995            1.746582  0.103769       1.539740          0.046021
# 996            0.704407  0.224613       1.398429          1.254543
# 997            0.642767  0.541611       1.448920          0.125944
# 998            2.208028  2.523284       0.047867          0.358447
# 999            2.190645  2.304363       0.038303          0.418985
#
#      policy_state  policy_csl  policy_deductable  policy_annual_premium  \
# 0        1.187173    0.060937           0.222383               0.616705
# ...

# %% [markdown]
# Using the zscore method to remove the outliers from the orginal dataset df

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([ 31,  48,  88, 115, 119, 229, 248, 262, 314, 430, 458, 500, 503,
#        657, 700, 763, 807, 875, 922, 975], dtype=int64), array([ 8,  8,  8,  8,  8,  7,  7,  8,  8,  8,  8, 33,  8,  8,  8,  7, 16,
#         8,  8,  8], dtype=int64))

# %% [markdown]
# setting the threshold to 3 ,because 99.9% of data is present in -3 to +3 std

# %%
df1=df[(z<3).all(axis=1)]

# %% [markdown]
# after removing the outliers saving the model to df1 variable

# %%
print(df.shape)
print(df1.shape)
# Out:
# (1000, 39)
# (980, 39)

# %% [markdown]
# we can see the outliers are removed from df dataset

# %%
df1.corr()
# Out:
#                              months_as_customer       age  policy_number  \
# months_as_customer                     1.000000  0.922960       0.061267
# age                                    0.922960  1.000000       0.062332
# policy_number                          0.061267  0.062332       1.000000
# policy_bind_date                       0.055337  0.057015       0.054617
# policy_state                          -0.007183 -0.020012       0.071343
# policy_csl                            -0.021855 -0.013323       0.042129
# policy_deductable                      0.031041  0.032036      -0.009812
# policy_annual_premium                 -0.003814  0.005330       0.028686
# umbrella_limit                         0.018213  0.013256      -0.000145
# insured_zip                            0.029572  0.035864       0.004531
# insured_sex                            0.059644  0.073790       0.007069
# insured_education_level               -0.000731  0.001647      -0.033767
# ...

# %%
plt.figure(figsize=(40,40))
sns.heatmap(data=df1.corr(),linecolor='black',linewidth=0.20,fmt='0.2f',cmap='Paired',annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# using the corr function to check the co reletion of dataset

# %%
df1.skew()
# Out:
# months_as_customer             0.362608
# age                            0.475385
# policy_number                  0.036283
# policy_bind_date               0.006386
# policy_state                  -0.038157
# policy_csl                     0.098248
# policy_deductable              0.476090
# policy_annual_premium          0.035964
# umbrella_limit                 1.801424
# insured_zip                    0.837283
# insured_sex                    0.139324
# insured_education_level        0.006286
# insured_occupation            -0.055360
# insured_hobbies               -0.061488
# insured_relationship           0.078339
# capital-gains                  0.466619
# capital-loss                  -0.376884
# incident_date                  0.002604
# incident_type                  0.090563
# collision_type                -0.194015
# incident_severity              0.277726
# authorities_contacted         -0.114044
# incident_state                -0.149255
# ...

# %% [markdown]
# umbrella_limit column has skewness , we need to remove the skewness

# %%
df1['umbrella_limit']=np.sqrt(df1['umbrella_limit'])

# %% [markdown]
# using numpy square root method to remove the skewness

# %%
df1.dropna(axis=0,inplace=True)

# %% [markdown]
# droping the null value rows from the dataset

# %%
df1.skew()
# Out:
# months_as_customer             0.364465
# age                            0.476197
# policy_number                  0.036025
# policy_bind_date               0.004706
# policy_state                  -0.036279
# policy_csl                     0.096461
# policy_deductable              0.474601
# policy_annual_premium          0.036946
# umbrella_limit                 1.648539
# insured_zip                    0.835841
# insured_sex                    0.141529
# insured_education_level        0.005217
# insured_occupation            -0.055821
# insured_hobbies               -0.060795
# insured_relationship           0.079587
# capital-gains                  0.464949
# capital-loss                  -0.375180
# incident_date                  0.003303
# incident_type                  0.092483
# collision_type                -0.192558
# incident_severity              0.276441
# authorities_contacted         -0.115788
# incident_state                -0.150831
# ...

# %% [markdown]
# now little skewness is removed from the column

# %%
x=df1.iloc[:,:-1]
x
# Out:
#      months_as_customer  age  policy_number  policy_bind_date  policy_state  \
# 0                   328   48         521585             532.0           2.0
# 1                   228   42         342868             821.0           1.0
# 2                   134   29         687698             186.0           2.0
# 3                   256   41         227811             766.0           0.0
# 4                   228   44         367455             181.0           0.0
# ..                  ...  ...            ...               ...           ...
# 995                   3   38         941851             487.0           2.0
# 996                 285   41         186934             129.0           0.0
# 997                 130   34         918516             509.0           2.0
# 998                 458   62         533940             573.0           0.0
# 999                 456   60         556080             359.0           2.0
#
# ...

# %% [markdown]
# separating the independent variables and saving as x

# %%
y=df1.iloc[:,-1]
y
# Out:
# 0      1.0
# 1      1.0
# 2      0.0
# 3      1.0
# 4      0.0
#       ...
# 995    0.0
# 996    0.0
# 997    0.0
# 998    0.0
# 999    0.0
# Name: fraud_reported, Length: 979, dtype: float64

# %% [markdown]
# saving the dependent variable as y

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=pd.DataFrame(sc.fit_transform(x),columns=x.columns)
x
# Out:
#      months_as_customer       age  policy_number  policy_bind_date  \
# 0              1.069984  0.983241      -0.095805          0.210805
# 1              0.203374  0.329897      -0.789924          1.259036
# 2             -0.611238 -1.085680       0.549361         -1.044171
# 3              0.446025  0.221007      -1.236794          1.059546
# 4              0.203374  0.547679      -0.694431         -1.062306
# ..                  ...       ...            ...               ...
# 974           -1.746497 -0.105665       1.536466          0.047586
# 975            0.697342  0.221007      -1.395556         -1.250915
# 976           -0.645903 -0.541227       1.445835          0.127382
# 977            2.196576  2.507709      -0.047820          0.359516
# 978            2.179244  2.289928       0.038170         -0.416683
#
#      policy_state  policy_csl  policy_deductable  policy_annual_premium  \
# 0        1.181263    0.066043          -0.225719               0.620095
# ...

# %% [markdown]
# with the help of standardscaler , standrdzing the values with mean equal to zero and std +1 to -1

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# to check the biasness or variance using VIF function

# %%
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif['VIF Features']=x.columns
vif
# Out:
#     VIF Values                 VIF Features
# 0     6.850137           months_as_customer
# 1     6.866815                          age
# 2     1.030656                policy_number
# 3     1.030336             policy_bind_date
# 4     1.031825                 policy_state
# 5     1.024784                   policy_csl
# 6     1.028761            policy_deductable
# 7     1.037383        policy_annual_premium
# 8     1.035063               umbrella_limit
# 9     1.036247                  insured_zip
# 10    1.027506                  insured_sex
# 11    1.033013      insured_education_level
# 12    1.019173           insured_occupation
# 13    1.045238              insured_hobbies
# 14    1.051812         insured_relationship
# 15    1.036064                capital-gains
# 16    1.037239                 capital-loss
# 17    1.032499                incident_date
# 18    5.165365                incident_type
# 19    1.295566               collision_type
# ...

# %% [markdown]
# total_claim_amount,injury_claim,property_claim and vehicle_claim columns showing vif value infinity , i am dropping these columns

# %%
x.drop(['total_claim_amount'],axis=1,inplace=True)

# %%
x.drop(['injury_claim'],axis=1,inplace=True)
x.drop(['property_claim'],axis=1,inplace=True)
x.drop(['vehicle_claim'],axis=1,inplace=True)

# %%
vif=pd.DataFrame()
vif['VIF Values']=[variance_inflation_factor(x.values,i)
                  for i in range(len(x.columns))]
vif['VIF Features']=x.columns
vif
# Out:
#     VIF Values                 VIF Features
# 0     6.850137           months_as_customer
# 1     6.866815                          age
# 2     1.030656                policy_number
# 3     1.030336             policy_bind_date
# 4     1.031825                 policy_state
# 5     1.024784                   policy_csl
# 6     1.028761            policy_deductable
# 7     1.037383        policy_annual_premium
# 8     1.035063               umbrella_limit
# 9     1.036247                  insured_zip
# 10    1.027506                  insured_sex
# 11    1.033013      insured_education_level
# 12    1.019173           insured_occupation
# 13    1.045238              insured_hobbies
# 14    1.051812         insured_relationship
# 15    1.036064                capital-gains
# 16    1.037239                 capital-loss
# 17    1.032499                incident_date
# 18    5.165365                incident_type
# 19    1.295566               collision_type
# ...

# %% [markdown]
# now vif values are in range only

# %%
from imblearn.over_sampling import SMOTE
sm=SMOTE()
x,y=sm.fit_resample(x,y)

# %% [markdown]
# to resample the value counts of target variable using the smote function

# %%
y.value_counts()
# Out:
# 1.0    739
# 0.0    739
# Name: fraud_reported, dtype: int64

# %% [markdown]
# now both prediction has equal number of value counts

# %% [markdown]
# # Modelling

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,classification_report,confusion_matrix

# %%
maxAccu=0
maxRs=0

for i in range(1,1000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=i)
    dtc=DecisionTreeClassifier()
    dtc.fit(x_train,y_train)
    pred=dtc.predict(x_test)
    accu=accuracy_score(y_test,pred)
    if accu>maxAccu:
        maxAccu=accu
        maxRs=i
print('Best Accuracy is ',maxAccu,'at the random state of ',maxRs)
# Out:
# Best Accuracy is  0.8941441441441441 at the random state of  17

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.30,random_state=maxRs)
from sklearn.ensemble import GradientBoostingClassifier,AdaBoostClassifier,BaggingClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier,ExtraTreesClassifier

# %%
print('DecisionTreeClassidfier')
preddtc=dtc.predict(x_test)
preddtc_train=dtc.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,preddtc)*100)
print('Accuracy score on train data',accuracy_score(y_train,preddtc_train)*100)
print('Classification Report','\n',classification_report(y_test,preddtc))
print('Confusion Matrix','\n',confusion_matrix(y_test,preddtc))
# Out:
# DecisionTreeClassidfier
# Accuracy score on test data 96.3963963963964
# Accuracy score on train data 95.45454545454545
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.97      0.97      0.97       234
#          1.0       0.96      0.96      0.96       210
#
#     accuracy                           0.96       444
#    macro avg       0.96      0.96      0.96       444
# weighted avg       0.96      0.96      0.96       444
#
# Confusion Matrix
#  [[226   8]
#  [  8 202]]

# %%
print('SupportVector')
svc=SVC()
svc.fit(x_train,y_train)
predsvc=svc.predict(x_test)
predsvc_train=svc.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predsvc)*100)
print('Accuracy score on train data',accuracy_score(y_train,predsvc_train)*100)
print('Classification report','\n',classification_report(y_test,predsvc))
print('Confusion Matrix','\n',confusion_matrix(y_test,predsvc))
# Out:
# SupportVector
# Accuracy score on test data 86.26126126126125
# Accuracy score on train data 96.42166344294004
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.88      0.86      0.87       234
#          1.0       0.85      0.87      0.86       210
#
#     accuracy                           0.86       444
#    macro avg       0.86      0.86      0.86       444
# weighted avg       0.86      0.86      0.86       444
#
# Confusion Matrix
#  [[201  33]
#  [ 28 182]]

# %%
print('GradientBoostingClassifier')
gb=GradientBoostingClassifier()
gb.fit(x_train,y_train)
predgb=gb.predict(x_test)
predgb_train=gb.predict(x_train)
print('Accurcy score on test data ',accuracy_score(y_test,predgb)*100)
print('Accuracy score on train data',accuracy_score(y_train,predgb_train)*100)
print('Classification report','\n',classification_report(y_test,predgb))
print('Confusion matrix','\n',confusion_matrix(y_test,predgb))
# Out:
# GradientBoostingClassifier
# Accurcy score on test data  90.09009009009009
# Accuracy score on train data 97.678916827853
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.93      0.88      0.90       234
#          1.0       0.87      0.93      0.90       210
#
#     accuracy                           0.90       444
#    macro avg       0.90      0.90      0.90       444
# weighted avg       0.90      0.90      0.90       444
#
# Confusion matrix
#  [[205  29]
#  [ 15 195]]

# %%
print('AdaBoostClassifier')
ad=AdaBoostClassifier()
ad.fit(x_train,y_train)
predad=ad.predict(x_test)
predad_train=ad.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predad)*100)
print('Accuracy score on train data',accuracy_score(y_train,predad_train)*100)
print('Classification Report','\n',classification_report(y_test,predad))
print('Confusion Matrix','\n',confusion_matrix(y_test,predad))
# Out:
# AdaBoostClassifier
# Accuracy score on test data 85.8108108108108
# Accuracy score on train data 89.94197292069632
# Classification Report
#                precision    recall  f1-score   support
#
#          0.0       0.86      0.87      0.87       234
#          1.0       0.86      0.84      0.85       210
#
#     accuracy                           0.86       444
#    macro avg       0.86      0.86      0.86       444
# weighted avg       0.86      0.86      0.86       444
#
# Confusion Matrix
#  [[204  30]
#  [ 33 177]]

# %%
print('baggingClassifier')
bg=BaggingClassifier()
bg.fit(x_train,y_train)
predbg=bg.predict(x_test)
predbg_train=bg.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predbg)*100)
print('Accuracy score on train data',accuracy_score(y_train,predbg_train)*100)
print('Classification report','\n',classification_report(y_test,predbg))
print('Confusion Matrix','\n',confusion_matrix(y_test,predbg))
# Out:
# baggingClassifier
# Accuracy score on test data 88.96396396396396
# Accuracy score on train data 99.32301740812379
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.89      0.90      0.90       234
#          1.0       0.89      0.88      0.88       210
#
#     accuracy                           0.89       444
#    macro avg       0.89      0.89      0.89       444
# weighted avg       0.89      0.89      0.89       444
#
# Confusion Matrix
#  [[211  23]
#  [ 26 184]]

# %%
print('RandomForestClassifier')
rf=RandomForestClassifier()
rf.fit(x_train,y_train)
predrf=rf.predict(x_test)
predrf_train=rf.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predrf)*100)
print('Accuracy score on train data',accuracy_score(y_train,predrf_train)*100)
print('Classification report','\n',classification_report(y_test,predrf))
print('Confusion matrix','\n',confusion_matrix(y_test,predrf))
# Out:
# RandomForestClassifier
# Accuracy score on test data 88.96396396396396
# Accuracy score on train data 100.0
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.91      0.88      0.89       234
#          1.0       0.87      0.90      0.89       210
#
#     accuracy                           0.89       444
#    macro avg       0.89      0.89      0.89       444
# weighted avg       0.89      0.89      0.89       444
#
# Confusion matrix
#  [[206  28]
#  [ 21 189]]

# %%
print('ExtraTreesClassifier')
et=ExtraTreesClassifier()
et.fit(x_train,y_train)
predet=et.predict(x_test)
predet_train=et.predict(x_train)
print('Accuracy score on test data',accuracy_score(y_test,predet)*100)
print('Accuracy score on train data',accuracy_score(y_train,predet_train)*100)
print('Classification report','\n',classification_report(y_test,predet))
print('Confusion matrix','\n',confusion_matrix(y_test,predet))
# Out:
# ExtraTreesClassifier
# Accuracy score on test data 90.76576576576578
# Accuracy score on train data 100.0
# Classification report
#                precision    recall  f1-score   support
#
#          0.0       0.93      0.89      0.91       234
#          1.0       0.89      0.92      0.90       210
#
#     accuracy                           0.91       444
#    macro avg       0.91      0.91      0.91       444
# weighted avg       0.91      0.91      0.91       444
#
# Confusion matrix
#  [[209  25]
#  [ 16 194]]

# %%
from sklearn.model_selection import cross_val_score

# %%
print('***ExtraTreesClassifier***')
scoreet=cross_val_score(et,x,y,cv=10)
print('Score',scoreet*100)
print('Mean score',scoreet.mean()*100)
# Out:
# ***ExtraTreesClassifier***
# Score [85.13513514 86.48648649 85.13513514 89.18918919 93.91891892 91.89189189
#  92.56756757 97.2972973  96.59863946 93.87755102]
# Mean score 91.2097812097812

# %%
print('***RandomForestClassifier***')
scorerf=cross_val_score(rf,x,y,cv=10)
print('Score',scorerf*100)
print('Mean score',scorerf.mean()*100)
# Out:
# ***RandomForestClassifier***
# Score [79.05405405 77.02702703 81.75675676 91.21621622 94.59459459 92.56756757
#  91.89189189 94.59459459 96.59863946 91.83673469]
# Mean score 89.11380768523627

# %%
print('***BaggingClassifier***')
scorebg=cross_val_score(bg,x,y,cv=10)
print('Score',scorebg*100)
print('Mean score',scorebg.mean()*100)
# Out:
# ***BaggingClassifier***
# Score [83.78378378 86.48648649 81.75675676 87.83783784 88.51351351 89.86486486
#  89.86486486 92.56756757 92.5170068  93.87755102]
# Mean score 88.7070233498805

# %%
print('***AdaBoostClassifier***')
scoread=cross_val_score(ad,x,y,cv=10)
print('score',scoread*100)
print('mean score',scoread.mean()*100)
# Out:
# ***AdaBoostClassifier***
# score [67.56756757 72.2972973  74.32432432 86.48648649 91.21621622 91.89189189
#  91.21621622 95.27027027 95.23809524 95.91836735]
# mean score 86.14267328553045

# %%
print('***DecisionTreeClassifier***')
scoredtc=cross_val_score(dtc,x,y,cv=10)
print('Score',scoredtc*100)
print('Mean score',scoredtc.mean()*100)
# Out:
# ***DecisionTreeClassifier***
# Score [70.27027027 74.32432432 77.7027027  85.13513514 87.83783784 87.83783784
#  86.48648649 89.86486486 91.83673469 91.15646259]
# Mean score 84.2452656738371

# %%
print('***SupportVector***')
scoresvc=cross_val_score(svc,x,y,cv=10)
print('score',scoresvc*100)
print('mean score',scoresvc.mean()*100)
# Out:
# ***SupportVector***
# score [79.72972973 83.78378378 80.40540541 85.13513514 90.54054054 87.83783784
#  89.18918919 95.27027027 91.83673469 91.15646259]
# mean score 87.48850891708034

# %%
print('***GradientBoostingClassifier***')
scoregb=cross_val_score(gb,x,y,cv=10)
print('Score',scoregb*100)
print('Mean score',scoregb.mean()*100)
# Out:
# ***GradientBoostingClassifier***
# Score [79.72972973 83.10810811 82.43243243 87.83783784 90.54054054 91.89189189
#  89.18918919 94.59459459 94.55782313 91.15646259]
# Mean score 88.50386100386099

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameters={'n_estimators':[100,200,500],
           'criterion':['gini','entropy'],
           'max_depth':[50,100,200],
           'random_state':[100,200,300,500],
           'n_jobs':[-2,-1,1]}

# %%
gscv=GridSearchCV(ExtraTreesClassifier(),parameters,cv=5)
gscv.fit(x_train,y_train)
gscv.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 50,
#  'n_estimators': 200,
#  'n_jobs': -2,
#  'random_state': 500}

# %%
model=ExtraTreesClassifier(criterion='gini',max_depth=50,n_estimators=200,n_jobs=-2,random_state=500)
model.fit(x_train,y_train)
pred=model.predict(x_test)
print('Accuracy score is ',accuracy_score(y_test,pred)*100)
# Out:
# Accuracy score is  90.09009009009009

# %%
import pickle
filename='Insurance_project'
pickle.dump(model,open(filename,'wb'))

# %%
final_model=pickle.load(open('Insurance_project','rb'))
final_model.score(x_test,y_test)*100
# Out:
# 90.09009009009009

# %% [markdown]
# Conclusion
